# %%
import pandas as pd
from openpyxl import load_workbook
import seaborn as sns
import matplotlib.pyplot as plt

# %%
butyrate_data = pd.read_excel("data/butyrate_pick.xlsx", index_col=0)
food_data = pd.read_csv('data/Summarized_Food_Categories_Only.csv', index_col=0)
participants_data = pd.read_csv('data/demo_535.csv', index_col=0)

# %%
# Selecting the first and ninth columns by index, assuming 'ID' is the first column
participants_reduced = participants_data.iloc[:, [7]]
participants_reduced
# Out:
#                FREG5_Ethnic_Group
# Participant_ID
# 10457                           C
# 10924                           M
# 7036                            M
# 10529                           C
# 10420                           I
# ...                           ...
# 10147                           C
# 10546                           M
# 10058                           I
# 10504                           M
# 10887                           M
#
# [535 rows x 1 columns]

# %%
merged_data = pd.merge(participants_reduced, food_data, on='Participant_ID')
merged_data
# Out:
#                FREG5_Ethnic_Group  Fish  Crustacean  Mollusk  Seafood_dishes  \
# Participant_ID
# 10457                           C  0.78        0.14     0.08            0.94
# 10924                           M  0.27        0.08     0.00            0.24
# 7036                            M  0.14        0.36     0.00            0.50
# 10529                           C  0.80        0.44     0.16            1.32
# 10420                           I  0.00        0.00     0.00            0.00
# ...                           ...   ...         ...      ...             ...
# 10147                           C  0.43        0.14     0.00            0.30
# 10546                           M  0.28        0.00     0.00            0.28
# 10058                           I  1.23        0.11     0.03            1.21
# 10504                           M  0.88        0.36     0.00            1.08
# 10887                           M  0.00        0.00     0.00            0.00
#
#                 Poultry  Red_meat  Meat_dishes  Processed_meat  Dairy  \
# Participant_ID
# 10457              0.86      0.42         0.36            0.17   1.22
# 10924              0.24      0.32         0.16            0.16   1.30
# 7036               0.72      0.16         0.16            0.00   0.00
# 10529              1.42      0.52         0.44            0.00   0.87
# 10420              0.00      0.08         0.00            0.00   1.80
# ...                 ...       ...          ...             ...    ...
# 10147              1.44      0.52         0.16            1.08   0.44
# 10546              0.72      0.22         0.22            0.00   1.36
# 10058              1.78      0.00         0.00            0.36   0.80
# 10504              0.24      1.44         1.00            0.44   3.93
# 10887              0.00      1.00         1.00            0.00   2.14
#
#                 Cruciferous_vegetables  Legumes  Mushroom  Fruits  Wholegrain  \
# Participant_ID
# 10457                             0.67     0.10      0.24    1.00      0.0600
# 10924                             0.02     0.09      0.00    0.22      0.3000
# 7036                              0.35     0.43      0.07    0.08      0.1475
# 10529                             0.94     0.20      0.10    2.50      1.0700
# 10420                             0.12     0.15      0.00    2.00      0.5000
# ...                                ...      ...       ...     ...         ...
# 10147                             0.18     0.01      0.01    0.03      0.8300
# 10546                             0.49     0.14      0.04    0.36      2.4400
# 10058                             0.09     0.84      0.12    1.00      0.7200
# 10504                             0.25     0.38      0.00    1.00      2.5075
# 10887                             0.59     0.06      0.01    1.00      1.0000
#
#                 Chapati  Noodle_dishes  Deep_fried  Coffee   Tea
# Participant_ID
# 10457              0.00          0.680        0.17    1.00  0.36
# 10924              0.00          0.640        0.19    1.00  1.00
# 7036               0.00          1.000        0.03    2.50  0.00
# 10529              0.00          0.880        0.00    1.00  0.14
# 10420              1.00          0.165        0.14    0.00  0.00
# ...                 ...            ...         ...     ...   ...
# 10147              0.00          4.540        0.47    2.50  0.00
# 10546              0.00          0.560        0.03    1.00  0.00
# 10058              0.08          1.980        0.11    0.36  1.00
# 10504              0.00          0.840        0.87    1.00  0.71
# 10887              0.00          1.180        0.03    1.00  0.00
#
# [535 rows x 20 columns]

# %%
filtered_data = merged_data[merged_data['FREG5_Ethnic_Group'] != 'O']
grouped_data = filtered_data.groupby('FREG5_Ethnic_Group').mean()
#correlation_matrix = grouped_data.corr()
#correlation_matrix

# %%
#plt.figure(figsize=(10, 8))
#sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
#plt.title('Correlation Heatmap of Food Intake by Ethnic Group')
#plt.show()
grouped_data2 = grouped_data.clip(lower=0.2, upper=1)
grouped_data2
# Out:
#                         Fish  Crustacean  Mollusk  Seafood_dishes   Poultry  \
# FREG5_Ethnic_Group
# C                   0.373028         0.2      0.2        0.417048  0.883232
# I                   0.446374         0.2      0.2        0.489451  0.955934
# M                   0.402653         0.2      0.2        0.460000  0.579184
#
#                     Red_meat  Meat_dishes  Processed_meat     Dairy  \
# FREG5_Ethnic_Group
# C                   0.413155     0.322595        0.200000  0.688066
# I                   0.388571     0.285934        0.265495  0.651538
# M                   0.431224     0.350816        0.200000  0.790816
#
#                     Cruciferous_vegetables   Legumes  Mushroom    Fruits  \
# FREG5_Ethnic_Group
# C                                 0.414020  0.324631       0.2  0.790789
# I                                 0.416374  0.312857       0.2  1.000000
# M                                 0.377143  0.307959       0.2  0.948163
#
#                     Wholegrain  Chapati  Noodle_dishes  Deep_fried    Coffee  \
# FREG5_Ethnic_Group
# C                     0.634453      0.2       0.962163    0.200000  0.912621
# I                     0.759313      0.2       1.000000    0.241319  0.941868
# M                     0.776735      0.2       0.880102    0.200000  1.000000
#
#                          Tea
# FREG5_Ethnic_Group
# C                   0.493384
# I                   0.535934
# M                   0.364082

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import seaborn as sns
import matplotlib.pyplot as plt

# Generate the linkage matrix for clustering
Z = linkage(grouped_data.transpose(), 'ward')  # 'ward' is one method of clustering

# Plotting a dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z, labels=grouped_data2.columns, leaf_rotation=90)
plt.title('Dendrogram of Food Groups')
plt.xlabel('Food Groups')
plt.ylabel('Distance')
plt.show()

# %%
# Creating the clustered heatmap
sns.clustermap(grouped_data2, cmap='RdBu_r', fmt=".2f", linewidths=.5, method='ward', col_linkage=Z)
plt.title('Clustered Heatmap of Food Intake by Ethnic Group')
plt.show()

# %%
# z score

# %%
from scipy.stats import zscore
from scipy.cluster.hierarchy import dendrogram, linkage
import seaborn as sns
import matplotlib.pyplot as plt

# Apply Z-score normalization
normalized_data = grouped_data.apply(zscore)
#normalized_data2 = normalized_data.clip(lower=-1, upper=1)


# Clustering
Z = linkage(normalized_data.transpose(), 'ward')

# Dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z, labels=normalized_data.columns, leaf_rotation=90)
plt.title('Dendrogram of Food Groups - Z-Score Normalized')
plt.xlabel('Food Groups')
plt.ylabel('Distance')
plt.show()

# Clustered heatmap
sns.clustermap(normalized_data, cmap='RdBu_r', fmt=".2f", linewidths=.5, method='ward', col_linkage=Z)
plt.title('Clustered Heatmap of Z-Score Normalized Food Intake by Ethnic Group')
plt.show()

# %%
# logtransform

# %%
import numpy as np

# Apply logarithmic transformation, adding 1 to avoid log(0)
log_transformed_data = np.log1p(grouped_data)

# Clustering and heatmap visualization
Z = linkage(log_transformed_data.transpose(), 'ward')

# Dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z, labels=log_transformed_data.columns, leaf_rotation=90)
plt.title('Dendrogram of Food Groups - Log Transformed')
plt.xlabel('Food Groups')
plt.ylabel('Distance')
plt.show()

# Clustered heatmap
sns.clustermap(log_transformed_data, cmap='RdBu_r', fmt=".2f", linewidths=.5, method='ward', col_linkage=Z)
plt.title('Clustered Heatmap of Log Transformed Food Intake by Ethnic Group')
plt.show()

# %%
#min-max

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(grouped_data)
scaled_data = pd.DataFrame(scaled_data, index=grouped_data.index, columns=grouped_data.columns)

# Clustering and heatmap visualization
Z = linkage(scaled_data.transpose(), 'ward')

# Dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z, labels=scaled_data.columns, leaf_rotation=90)
plt.title('Dendrogram of Food Groups - Log Transformed')
plt.xlabel('Food Groups')
plt.ylabel('Distance')
plt.show()

# Clustered heatmap
sns.clustermap(scaled_data, cmap='RdBu_r', fmt=".2f", linewidths=.5, method='ward', col_linkage=Z)
plt.title('Clustered Heatmap of Log Transformed Food Intake by Ethnic Group')
plt.show()

# %%
## violin plot

# %%
melted_data = pd.melt(filtered_data, id_vars=['FREG5_Ethnic_Group'], var_name='Food_Group', value_name='Intake')
melted_data
# Out:
#       FREG5_Ethnic_Group Food_Group  Intake
# 0                      C       Fish    0.78
# 1                      M       Fish    0.27
# 2                      M       Fish    0.14
# 3                      C       Fish    0.80
# 4                      I       Fish    0.00
# ...                  ...        ...     ...
# 10122                  C        Tea    0.00
# 10123                  M        Tea    0.00
# 10124                  I        Tea    1.00
# 10125                  M        Tea    0.71
# 10126                  M        Tea    0.00
#
# [10127 rows x 3 columns]

# %%
ethnicity_colors = {
    "C": "#B24745FF",
    "I": "#79AF97FF",
    "M": "#DF8F44FF",
    "O": "#80796BFF"
}



melted_data['FREG5_Ethnic_Group'] = pd.Categorical(melted_data['FREG5_Ethnic_Group'], categories=['C', 'I', 'M'], ordered=True)
melted_data = melted_data.sort_values('FREG5_Ethnic_Group')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the overall context for better font size and plot size
sns.set_context("notebook", font_scale=1.5)  # Increase font scale for better readability
plt.figure(figsize=(24, 12))  # Set a large figure size to accommodate all data

# Create the violin plot
ax = sns.violinplot(x='Food_Group', y='Intake', hue='FREG5_Ethnic_Group', data=melted_data,
               inner='quartile', scale='width', palette=ethnicity_colors)

plt.title('Violin Plots of Food Intake by Ethnic Group Across Different Food Groups')
plt.xticks(rotation=90)  # Rotate the x labels to 90 degrees for better visibility
plt.xlabel('Food Group')
plt.ylabel('Intake')
plt.legend(title='Ethnic Group', loc='upper right', fontsize='large', title_fontsize='x-large')

# Adjust the bottom margin to prevent labels from being cut off
plt.subplots_adjust(bottom=0.3)  # Adjust the bottom margin to give more space for labels

# Save the plot as a PNG file
plt.savefig('figure/Food_Ethnic_violin.png', format='png', dpi=300, bbox_inches='tight')  # Save with tight bounding box to include all elements
plt.show()

# %%
# outliner in noodle dishes

# %%
def remove_outliers(df, lower_percentile=1, upper_percentile=99):
    for food_group in df['Food_Group'].unique():
        # Calculate lower and upper percentiles for each food group
        lower_bound = df[df['Food_Group'] == food_group]['Intake'].quantile(lower_percentile/100)
        upper_bound = df[df['Food_Group'] == food_group]['Intake'].quantile(upper_percentile/100)

        df = df[~((df['Food_Group'] == food_group) & ((df['Intake'] < lower_bound) | (df['Intake'] > upper_bound)))]
        
    return df

# %%
filtered_data2 = remove_outliers(melted_data)

# %%
# Set the overall context for better font size and plot size
sns.set_context("notebook", font_scale=1.5)  # Increase font scale for better readability
plt.figure(figsize=(24, 12))  # Set a large figure size to accommodate all data

# Create the violin plot with the filtered data
ax = sns.violinplot(x='Food_Group', y='Intake', hue='FREG5_Ethnic_Group', data=filtered_data2,
               inner='quartile', scale='width', palette=ethnicity_colors)

plt.title('Violin Plots of Food Intake by Ethnic Group Across Different Food Groups (Filtered)')
plt.xticks(rotation=90)  # Rotate the x labels to 90 degrees for better visibility
plt.xlabel('Food Group')
plt.ylabel('Intake')
plt.legend(title='Ethnic Group', loc='upper right', fontsize='large', title_fontsize='x-large')

# Adjust the bottom margin to prevent labels from being cut off
plt.subplots_adjust(bottom=0.3)  # Adjust the bottom margin to give more space for labels

# Save the plot as a PNG file
plt.savefig('figure/Food_Ethnic_violin_filtered.png', format='png', dpi=300, bbox_inches='tight')  # Save with tight bounding box to include all elements
plt.show()

# %%
# box plot

# %%
# Set the overall context for better font size and plot size
sns.set_context("notebook", font_scale=1.5)  # Increase font scale for better readability
plt.figure(figsize=(24, 12))  # Set a large figure size to accommodate all data

# Create the boxplot with the filtered data
ax = sns.boxplot(x='Food_Group', y='Intake', hue='FREG5_Ethnic_Group', data=filtered_data2,
                 palette=ethnicity_colors)

plt.title('Box Plots of Food Intake by Ethnic Group Across Different Food Groups (Filtered)')
plt.xticks(rotation=90)  # Rotate the x labels to 90 degrees for better visibility
plt.xlabel('Food Group')
plt.ylabel('Intake')
plt.legend(title='Ethnic Group', loc='upper right', fontsize='large', title_fontsize='x-large')

# Adjust the bottom margin to prevent labels from being cut off
plt.subplots_adjust(bottom=0.3)  # Adjust the bottom margin to give more space for labels

# Save the plot as a PNG file
plt.savefig('figure/Food_Ethnic_box_filtered.png', format='png', dpi=300, bbox_inches='tight')  # Save with tight bounding box to include all elements
plt.show()

# %%
# Out:
# Results for Fruits:
# Multiple Comparison of Means - Tukey HSD, FWER=0.20
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      C      I   0.2434 0.0407  0.0715 0.4153   True
#      C      M   0.1574 0.4513 -0.0664 0.3812  False
#      I      M   -0.086 0.8212 -0.3478 0.1758  False
# ---------------------------------------------------

# %%
# Out:
# Results for Fish:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.20541
# Method:                          IRLS   Log-Likelihood:                -332.99
# Date:                Tue, 18 Jun 2024   Deviance:                       108.87
# Time:                        16:11:16   Pearson chi2:                     109.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.3730      0.023     16.317      0.000       0.328       0.418
# C(FREG5_Ethnic_Group)[T.I]     0.0733      0.053      1.391      0.164      -0.030       0.177
# C(FREG5_Ethnic_Group)[T.M]     0.0296      0.069      0.431      0.666      -0.105       0.164
# ==============================================================================================
#
# Results for Mushroom:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                       0.0082565
# Method:                          IRLS   Log-Likelihood:                 523.54
# Date:                Tue, 18 Jun 2024   Deviance:                       4.3760
# Time:                        16:11:16   Pearson chi2:                     4.38
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.0632      0.005     13.795      0.000       0.054       0.072
# C(FREG5_Ethnic_Group)[T.I]    -0.0016      0.011     -0.150      0.881      -0.022       0.019
# C(FREG5_Ethnic_Group)[T.M]     0.0202      0.014      1.470      0.142      -0.007       0.047
# ==============================================================================================
#
# Results for Fruits:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.74048
# Method:                          IRLS   Log-Likelihood:                -674.72
# Date:                Tue, 18 Jun 2024   Deviance:                       392.45
# Time:                        16:11:16   Pearson chi2:                     392.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.7908      0.043     18.218      0.000       0.706       0.876
# C(FREG5_Ethnic_Group)[T.I]     0.2434      0.100      2.431      0.015       0.047       0.440
# C(FREG5_Ethnic_Group)[T.M]     0.1574      0.130      1.207      0.227      -0.098       0.413
# ==============================================================================================
#
# Results for Legumes:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.12166
# Method:                          IRLS   Log-Likelihood:                -193.41
# Date:                Tue, 18 Jun 2024   Deviance:                       64.482
# Time:                        16:11:16   Pearson chi2:                     64.5
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.3246      0.018     18.450      0.000       0.290       0.359
# C(FREG5_Ethnic_Group)[T.I]    -0.0118      0.041     -0.290      0.772      -0.091       0.068
# C(FREG5_Ethnic_Group)[T.M]    -0.0167      0.053     -0.315      0.752      -0.120       0.087
# ==============================================================================================
#
# Results for Wholegrain:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.76110
# Method:                          IRLS   Log-Likelihood:                -682.04
# Date:                Tue, 18 Jun 2024   Deviance:                       403.38
# Time:                        16:11:16   Pearson chi2:                     403.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.6345      0.044     14.417      0.000       0.548       0.721
# C(FREG5_Ethnic_Group)[T.I]     0.1249      0.101      1.230      0.219      -0.074       0.324
# C(FREG5_Ethnic_Group)[T.M]     0.1423      0.132      1.076      0.282      -0.117       0.401
# ==============================================================================================
#
# Results for Dairy:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.68176
# Method:                          IRLS   Log-Likelihood:                -652.70
# Date:                Tue, 18 Jun 2024   Deviance:                       361.33
# Time:                        16:11:16   Pearson chi2:                     361.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.6881      0.042     16.520      0.000       0.606       0.770
# C(FREG5_Ethnic_Group)[T.I]    -0.0365      0.096     -0.380      0.704      -0.225       0.152
# C(FREG5_Ethnic_Group)[T.M]     0.1028      0.125      0.821      0.411      -0.142       0.348
# ==============================================================================================
#
# Results for Cruciferous_vegetables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.14005
# Method:                          IRLS   Log-Likelihood:                -230.91
# Date:                Tue, 18 Jun 2024   Deviance:                       74.225
# Time:                        16:11:16   Pearson chi2:                     74.2
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.4140      0.019     21.932      0.000       0.377       0.451
# C(FREG5_Ethnic_Group)[T.I]     0.0024      0.044      0.054      0.957      -0.083       0.088
# C(FREG5_Ethnic_Group)[T.M]    -0.0369      0.057     -0.650      0.515      -0.148       0.074
# ==============================================================================================
#
# Results for Coffee:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.93975
# Method:                          IRLS   Log-Likelihood:                -738.23
# Date:                Tue, 18 Jun 2024   Deviance:                       498.07
# Time:                        16:11:16   Pearson chi2:                     498.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.9126      0.049     18.663      0.000       0.817       1.008
# C(FREG5_Ethnic_Group)[T.I]     0.0292      0.113      0.259      0.795      -0.192       0.250
# C(FREG5_Ethnic_Group)[T.M]     0.1347      0.147      0.917      0.359      -0.153       0.423
# ==============================================================================================
#
# Results for Deep_fried:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.10527
# Method:                          IRLS   Log-Likelihood:                -154.85
# Date:                Tue, 18 Jun 2024   Deviance:                       55.796
# Time:                        16:11:16   Pearson chi2:                     55.8
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.1999      0.016     12.212      0.000       0.168       0.232
# C(FREG5_Ethnic_Group)[T.I]     0.0414      0.038      1.098      0.272      -0.033       0.115
# C(FREG5_Ethnic_Group)[T.M]    -0.0203      0.049     -0.413      0.680      -0.117       0.076
# ==============================================================================================
#
# Results for Tea:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.49232
# Method:                          IRLS   Log-Likelihood:                -565.94
# Date:                Tue, 18 Jun 2024   Deviance:                       260.93
# Time:                        16:11:16   Pearson chi2:                     261.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.4934      0.035     13.940      0.000       0.424       0.563
# C(FREG5_Ethnic_Group)[T.I]     0.0425      0.082      0.521      0.602      -0.117       0.203
# C(FREG5_Ethnic_Group)[T.M]    -0.1293      0.106     -1.216      0.224      -0.338       0.079
# ==============================================================================================
#
# Results for Chapati:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                        0.040524
# Method:                          IRLS   Log-Likelihood:                 99.570
# Date:                Tue, 18 Jun 2024   Deviance:                       21.478
# Time:                        16:11:16   Pearson chi2:                     21.5
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.0398      0.010      3.922      0.000       0.020       0.060
# C(FREG5_Ethnic_Group)[T.I]     0.0160      0.023      0.683      0.494      -0.030       0.062
# C(FREG5_Ethnic_Group)[T.M]     0.0047      0.030      0.153      0.878      -0.055       0.064
# ==============================================================================================
#
# Results for Noodle_dishes:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                          1.7356
# Method:                          IRLS   Log-Likelihood:                -901.73
# Date:                Tue, 18 Jun 2024   Deviance:                       919.88
# Time:                        16:11:16   Pearson chi2:                     920.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.9622      0.066     14.478      0.000       0.832       1.092
# C(FREG5_Ethnic_Group)[T.I]     0.1642      0.153      1.071      0.284      -0.136       0.465
# C(FREG5_Ethnic_Group)[T.M]    -0.0821      0.200     -0.411      0.681      -0.473       0.309
# ==============================================================================================
#
# Results for Poultry:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                          1.4237
# Method:                          IRLS   Log-Likelihood:                -848.94
# Date:                Tue, 18 Jun 2024   Deviance:                       754.58
# Time:                        16:11:16   Pearson chi2:                     755.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.8832      0.060     14.674      0.000       0.765       1.001
# C(FREG5_Ethnic_Group)[T.I]     0.0727      0.139      0.524      0.600      -0.199       0.345
# C(FREG5_Ethnic_Group)[T.M]    -0.3040      0.181     -1.682      0.093      -0.658       0.050
# ==============================================================================================
#
# Results for Seafood_dishes:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.25373
# Method:                          IRLS   Log-Likelihood:                -389.29
# Date:                Tue, 18 Jun 2024   Deviance:                       134.48
# Time:                        16:11:16   Pearson chi2:                     134.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.4170      0.025     16.413      0.000       0.367       0.467
# C(FREG5_Ethnic_Group)[T.I]     0.0724      0.059      1.236      0.217      -0.042       0.187
# C(FREG5_Ethnic_Group)[T.M]     0.0430      0.076      0.563      0.574      -0.107       0.193
# ==============================================================================================
#
# Results for Red_meat:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.26370
# Method:                          IRLS   Log-Likelihood:                -399.56
# Date:                Tue, 18 Jun 2024   Deviance:                       139.76
# Time:                        16:11:16   Pearson chi2:                     140.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.4132      0.026     15.950      0.000       0.362       0.464
# C(FREG5_Ethnic_Group)[T.I]    -0.0246      0.060     -0.412      0.681      -0.142       0.093
# C(FREG5_Ethnic_Group)[T.M]     0.0181      0.078      0.232      0.816      -0.134       0.171
# ==============================================================================================
#
# Results for Crustacean:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                        0.034556
# Method:                          IRLS   Log-Likelihood:                 142.03
# Date:                Tue, 18 Jun 2024   Deviance:                       18.315
# Time:                        16:11:16   Pearson chi2:                     18.3
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.1151      0.009     12.279      0.000       0.097       0.134
# C(FREG5_Ethnic_Group)[T.I]    -0.0090      0.022     -0.416      0.678      -0.051       0.033
# C(FREG5_Ethnic_Group)[T.M]     0.0008      0.028      0.028      0.978      -0.054       0.056
# ==============================================================================================
#
# Results for Mollusk:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                       0.0088311
# Method:                          IRLS   Log-Likelihood:                 505.62
# Date:                Tue, 18 Jun 2024   Deviance:                       4.6805
# Time:                        16:11:16   Pearson chi2:                     4.68
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.0444      0.005      9.367      0.000       0.035       0.054
# C(FREG5_Ethnic_Group)[T.I]    -0.0007      0.011     -0.061      0.951      -0.022       0.021
# C(FREG5_Ethnic_Group)[T.M]    -0.0166      0.014     -1.169      0.242      -0.045       0.011
# ==============================================================================================
#
# Results for Meat_dishes:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.20531
# Method:                          IRLS   Log-Likelihood:                -332.86
# Date:                Tue, 18 Jun 2024   Deviance:                       108.82
# Time:                        16:11:16   Pearson chi2:                     109.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.3226      0.023     14.114      0.000       0.278       0.367
# C(FREG5_Ethnic_Group)[T.I]    -0.0367      0.053     -0.695      0.487      -0.140       0.067
# C(FREG5_Ethnic_Group)[T.M]     0.0282      0.069      0.411      0.681      -0.106       0.163
# ==============================================================================================
#
# Results for Processed_meat:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Intake   No. Observations:                  533
# Model:                            GLM   Df Residuals:                      530
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                         0.20236
# Method:                          IRLS   Log-Likelihood:                -329.01
# Date:                Tue, 18 Jun 2024   Deviance:                       107.25
# Time:                        16:11:16   Pearson chi2:                     107.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.1691      0.023      7.450      0.000       0.125       0.214
# C(FREG5_Ethnic_Group)[T.I]     0.0964      0.052      1.843      0.065      -0.006       0.199
# C(FREG5_Ethnic_Group)[T.M]    -0.0733      0.068     -1.076      0.282      -0.207       0.060
# ==============================================================================================
